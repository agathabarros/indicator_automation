# %% [markdown]
# ### Step 1 - Import Files and Libraries

# %%
#import library
import pandas as pd
#import win32com.client as win32
import pathlib

# %%
#import and clean databases


emails = pd.read_excel(r'data_base/emails.xlsx')
stores = pd.read_csv(r'data_base/store.csv', encoding='latin1', sep=';')
sales = pd.read_excel(r'data_base/sales.xlsx')
display(emails)
display(stores)
display(sales)
# Out:
#                                Store      Manager  \
# 0                 Iguatemi Esplanada       Helena
# 1               Shopping Midway Mall        Alice
# 2                     Norte Shopping        Laura
# 3        Shopping Iguatemi Fortaleza      Manuela
# 4           Shopping União de Osasco    Valentina
# 5         Shopping Center Interlagos       Sophia
# 6                     Rio Mar Recife     Isabella
# 7                  Salvador Shopping      Heloisa
# 8         Rio Mar Shopping Fortaleza        Luiza
# 9   Shopping Center Leste Aricanduva        Julia
# 10                 Ribeirão Shopping       Lorena
# 11                  Shopping Morumbi        Livia
# 12         Parque Dom Pedro Shopping  Maria Luiza
# 13               Bourbon Shopping SP      Cecilia
# 14       Palladium Shopping Curitiba         Eloa
# 15         Passei das Águas Shopping       Miguel
# 16        Center Shopping Uberlândia       Arthur
# 17                   Shopping Recife       Heitor
# ...

# %% [markdown]
# ### Step 2 - Define Create a Table for each Store and Define the Indicator day

# %%
#include store name in sales

sales = sales.merge(stores, on='ID Store')
display(sales)
# Out:
#         Sales Code       Date  ID Store                Product  Quantity  \
# 0                1 2019-01-01         1                  Print         1
# 1                1 2019-01-01         1                T-shirt         2
# 2                1 2019-01-01         1             Plaid shoe         1
# 3               21 2019-01-02         1  Striped V -neck shirt         2
# 4               34 2019-01-02         1           Striped shoe         1
# ...            ...        ...       ...                    ...       ...
# 100994       69846 2019-12-25         8            Short Print         2
# 100995       69846 2019-12-25         8                  Print         5
# 100996       69850 2019-12-25         8                  Stamp         4
# 100997       69972 2019-12-26         8            Smooth suit         3
# 100998       69972 2019-12-26         8                  Print         5
#
#         Unit Value  Final Value               Store
# ...

# %%
#create dictionary for store the stores
# loc to filter what I want
dictionary_store = {}
for store in stores['Store']:
    dictionary_store[store] = sales.loc[sales['Store']==store, :]
display(dictionary_store['Norte Shopping'])
display(dictionary_store['Passei das Águas Shopping'])
# Out:
#       Sales Code       Date  ID Store                Product  Quantity  \
# 3980           2 2019-01-02         3                  Clock         3
# 3981           2 2019-01-02         3         Smooth slipper         1
# 3982           7 2019-01-02         3  Striped V -neck shirt         1
# 3983           7 2019-01-02         3                 Smooth         1
# 3984          73 2019-01-02         3        Plaid underwear         5
# ...          ...        ...       ...                    ...       ...
# 8154       69888 2019-12-25         3            Linen shoes         1
# 8155       69916 2019-12-25         3                   Suit         2
# 8156       69962 2019-12-25         3             Half -line         2
# 8157       69976 2019-12-26         3         Plaid sneakers         1
# 8158       69976 2019-12-26         3                   Coat         4
#
#       Unit Value  Final Value           Store
# 3980         200          600  Norte Shopping
# ...

# %%
#difine the indicator day
indicator_day = sales['Date'].max()
print(indicator_day)
print('{}/{}'.format(indicator_day.day, indicator_day.month))
# Out:
# 2019-12-26 00:00:00

# %% [markdown]
# ### Step 3 - Save the spreadsheet in the backup folder

# %%
#identify if the folder already exists
import pathlib

backup_path = pathlib.Path(r'backup_stores')

files_backup_path = backup_path.iterdir()

list_names_backup = [file.name for file in files_backup_path]
#for file in files_backup_path:
#    list_names_backup.append(file.name)

print(list_names_backup)

#save to folder

# %% [markdown]
# ### Step 4 - Calculate the indicator for 1 store

# %% [markdown]
# ### Step 5 - Send by email to the manager

# %% [markdown]
# ### Step 6 - Automate all stores

# %% [markdown]
# ### Step 7 - Create ranking for board

# %% [markdown]
# ### Step 8 - Send email to management
